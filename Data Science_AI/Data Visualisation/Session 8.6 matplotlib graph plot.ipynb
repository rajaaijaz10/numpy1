# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn, randint, uniform, sample
from pandas.plotting import andrews_curves
from pandas.plotting import scatter_matrix
df=sns.load_dataset('iris')

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
andrews_curves(df,'sepal_width')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-96ed9481cb7f> in <module>
# ----> 1 andrews_curves(df,'sepal_width')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwargs)
#     269     """
#     270     plot_backend = _get_plot_backend("matplotlib")
# --> 271     return plot_backend.andrews_curves(
#     272         frame=frame,
#     273         class_column=class_column,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwds)
#     243         row = df.iloc[i].values
#     244         f = function(row)
# --> 245         y = f(t)
#     246         kls = class_col.iat[i]
#     247         label = pprint_thing(kls)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/misc.py in f(t)
#     219
#     220             result += np.sum(
# --> 221                 coeffs[:, 0, np.newaxis] * np.sin(trig_args)
#     222                 + coeffs[:, 1, np.newaxis] * np.cos(trig_args),
#     223                 axis=0,
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
df.plot(style = 'r--', label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(legend = False, figsize = (10, 5), logy = True)
# Out:
# <AxesSubplot:>

# %%
df.head(0)

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length species
# 0           5.1           1.4  setosa
# 1           4.9           1.4  setosa
# 2           4.7           1.3  setosa
# 3           4.6           1.5  setosa
# 4           5.0           1.4  setosa

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width species
# 0          3.5          0.2  setosa
# 1          3.0          0.2  setosa
# 2          3.2          0.2  setosa
# 3          3.1          0.2  setosa
# 4          3.6          0.2  setosa

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)
# Out:
# <AxesSubplot:label='2fca69ca-7520-49f2-bc90-9683468c23a1'>

# %%
x.plot(figsize=(10,5), x_compat = False)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = True, layout = (2,3), figsize = (16,8))
plt.tight_layout()
