# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot(kind = 'area')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-de564c58337f> in <module>
#       1 from numpy.random import randn, randint, uniform, sample
# ----> 2 df.plot(kind = 'area')
#
# NameError: name 'df' is not defined

# %%
df.plot.area(stacked = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6fabaccd2ed8> in <module>
# ----> 1 df.plot.area(stacked = False)
#
# NameError: name 'df' is not defined

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
ax = df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = df['petal_width']*700)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10, C = 'sepal_width')
