# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df
# Out:
#                value
# 2019-06-07 -0.032517
# 2019-06-08 -2.319998
# 2019-06-09  0.701847
# 2019-06-10 -1.071062
# 2019-06-11  1.195007
# ...              ...
# 2022-02-26  0.489470
# 2022-02-27 -2.081264
# 2022-02-28 -0.691458
# 2022-03-01 -1.967912
# 2022-03-02  0.828951
#
# [1000 rows x 1 columns]

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.032517
# 2019-06-08 -2.352515
# 2019-06-09 -1.650668
# 2019-06-10 -2.721730
# 2019-06-11 -1.526724

# %%
ts = ts.cumsum()
print(type(ts))
ts.head()
# Out:
# <class 'pandas.core.series.Series'>
# 2019-06-07   -0.253965
# 2019-06-08    0.080787
# 2019-06-09   -0.690412
# 2019-06-10    0.058203
# 2019-06-11    1.181091
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(20,5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot(figsize=(20,7))
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')
print(type(iris))
iris
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis - samples')
ax.set_ylabel('Y Axis - Measurements')
# Out:
# Text(0, 0.5, 'Y Axis - Measurements')

# %%
aa=iris.loc[25:27]
aa=aa.append(iris.loc[75:77])
aa=aa.append(iris.loc[125:127])
#print (aa)
aa.plot(kind = 'bar',figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[19].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[77].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.iloc[129].plot.bar()
# Out:
# <AxesSubplot:>
