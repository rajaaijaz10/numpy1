# %%
import pandas as pd
import numpy as np

# %%
titanic_train = pd.read_csv(r'C:\Users\Shankar\Desktop\Data Science\work files\titanic_train.csv')

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
new_survived = pd.Categorical(titanic_train["Survived"])
new_survived = new_survived.rename_categories(["Died","Survived"])              

new_survived.describe()
# Out:
#             counts     freqs
# categories
# Died           549  0.616162
# Survived       342  0.383838

# %%
titanic_train["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
new_Pclass = pd.Categorical(titanic_train["Pclass"],
                           ordered=True)

new_Pclass = new_Pclass.rename_categories(["Class1","Class2","Class3"])     

new_Pclass.describe()
# Out:
#             counts     freqs
# categories
# Class1         216  0.242424
# Class2         184  0.206510
# Class3         491  0.551066

# %%
titanic_train["Pclass"] = new_Pclass

# %%
titanic_train["Survived"] = new_survived

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died  Class3
# 1            2  Survived  Class1
# 2            3  Survived  Class3
# 3            4  Survived  Class1
# 4            5      Died  Class3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train["Cabin"].unique()   # Check unique cabins
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
char_cabin = titanic_train["Cabin"].astype(str) # Convert data to str

new_Cabin = np.array([cabin[0] for cabin in char_cabin]) # Take first letter

new_Cabin = pd.Categorical(new_Cabin)

new_Cabin .describe()
# Out:
#             counts     freqs
# categories
# A               15  0.016835
# B               47  0.052750
# C               59  0.066218
# D               33  0.037037
# E               32  0.035915
# F               13  0.014590
# G                4  0.004489
# T                1  0.001122
# n              687  0.771044

# %%
titanic_train["Cabin"] = new_Cabin

# %%
titanic_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887      Died  Class2                     Montvila, Rev. Juozas
# 887          888  Survived  Class1              Graham, Miss. Margaret Edith
# 888          889      Died  Class3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890  Survived  Class1                     Behr, Mr. Karl Howell
# 890          891      Died  Class3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00     n        S
# 887  female  19.0      0      0      112053  30.00     B        S
# 888  female   NaN      1      2  W./C. 6607  23.45     n        S
# 889    male  26.0      0      0      111369  30.00     C        C
# 890    male  32.0      0      0      370376   7.75     n        Q

# %%
dummy_vector = pd.Series([1,None,3,None,7,8])

dummy_vector.isnull()

# %%
missing = np.where(titanic_train["Age"].isnull() == True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
#         839, 846, 849, 859, 863, 868, 878, 888], dtype=int64),)

# %%
titanic_train.loc[missing]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6      Died  Class3                          Moran, Mr. James
# 17            18  Survived  Class2              Williams, Mr. Charles Eugene
# 19            20  Survived  Class3                   Masselmani, Mrs. Fatima
# 26            27      Died  Class3                   Emir, Mr. Farred Chehab
# 28            29  Survived  Class3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860      Died  Class3                          Razi, Mr. Raihed
# 863          864      Died  Class3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869      Died  Class3               van Melkebeke, Mr. Philemon
# 878          879      Died  Class3                        Laleff, Mr. Kristo
# 888          889      Died  Class3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5      male  NaN      0      0      330877   8.4583     n        Q
# 17     male  NaN      0      0      244373  13.0000     n        S
# 19   female  NaN      0      0        2649   7.2250     n        C
# 26     male  NaN      0      0        2631   7.2250     n        C
# 28   female  NaN      0      0      330959   7.8792     n        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292     n        C
# 863  female  NaN      8      2    CA. 2343  69.5500     n        S
# 868    male  NaN      0      0      345777   9.5000     n        S
# 878    male  NaN      0      0      349217   7.8958     n        S
# 888  female  NaN      1      2  W./C. 6607  23.4500     n        S
#
# [177 rows x 12 columns]

# %%
len(missing[0])
# Out:
# 177

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died  Class3
# 1            2  Survived  Class1
# 2            3  Survived  Class3
# 3            4  Survived  Class1
# 4            5      Died  Class3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     n        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     n        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     n        S

# %%
index = np.where(titanic_train["Fare"] == max(titanic_train["Fare"]) )

index
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
titanic_train.loc[index]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259  Survived  Class1                    Ward, Miss. Anna
# 679          680  Survived  Class1  Cardeza, Mr. Thomas Drake Martinez
# 737          738  Survived  Class1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292     n        C
# 679    male  36.0      0      1  PC 17755  512.3292     B        C
# 737    male  35.0      0      0  PC 17755  512.3292     B        C

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]

most_family = np.where(titanic_train["Family"] == max(titanic_train["Family"]))

titanic_train.iloc[most_family]
# Out:
#      PassengerId Survived  Pclass                               Name     Sex  \
# 159          160     Died  Class3         Sage, Master. Thomas Henry    male
# 180          181     Died  Class3       Sage, Miss. Constance Gladys  female
# 201          202     Died  Class3                Sage, Mr. Frederick    male
# 324          325     Died  Class3           Sage, Mr. George John Jr    male
# 792          793     Died  Class3            Sage, Miss. Stella Anna  female
# 846          847     Died  Class3           Sage, Mr. Douglas Bullen    male
# 863          864     Died  Class3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked  Family
# 159  NaN      8      2  CA. 2343  69.55     n        S      10
# 180  NaN      8      2  CA. 2343  69.55     n        S      10
# 201  NaN      8      2  CA. 2343  69.55     n        S      10
# 324  NaN      8      2  CA. 2343  69.55     n        S      10
# 792  NaN      8      2  CA. 2343  69.55     n        S      10
# 846  NaN      8      2  CA. 2343  69.55     n        S      10
# 863  NaN      8      2  CA. 2343  69.55     n        S      10

# %%
# Task
