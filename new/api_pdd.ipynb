# %%
import requests
import pandas as pd


  #  http://api.weatherstack.com/historical
  #  ? access_key = YOUR_ACCESS_KEY
  #  & query = New York
  #  &historical_date_start=2015-10-21&historical_date_end = 2015-10-25

url1 = 'http://api.weatherstack.com/historical?access_key=c4ba102829c5e67c4038c989b87d047d&query=Srinagar&historical_date_start=2015-10-21&historical_date_end=2020-10-25'


url = 'http://api.weatherstack.com/current?access_key=c4ba102829c5e67c4038c989b87d047d&query=Ganderbal'
resp = requests.get(url)
print("---------")
type(resp)
data = resp.text
print(data)
data1=resp.json()
type(data1)
pd1=pd.DataFrame(data1)
pd1
# Out:
# ---------
# {"request":{"type":"City","query":"ganderbal","language":"en","unit":"m"},"location":{"name":"Ganderbal","country":"India","region":"Jammu and Kashmir","lat":"34.233","lon":"74.783","timezone_id":"Asia\/Kolkata","localtime":"2021-01-06 10:27","localtime_epoch":1609928820,"utc_offset":"5.50"},"current":{"observation_time":"04:57 AM","temperature":2,"weather_code":338,"weather_icons":["https:\/\/assets.weatherstack.com\/images\/wsymbols01_png_64\/wsymbol_0036_cloudy_with_heavy_snow_night.png"],"weather_descriptions":["Heavy snow"],"wind_speed":2,"wind_degree":197,"wind_dir":"SSW","pressure":1019,"precip":4.8,"humidity":100,"cloudcover":100,"feelslike":1,"uv_index":1,"visibility":2,"is_day":"yes"}}
#                         request           location  \
# type                       City                NaN
# query                 ganderbal                NaN
# language                     en                NaN
# unit                          m                NaN
# ...
