# %%
import pandas as pd
import numpy as np
df = pd.read_csv('chipotle.csv')

# %%
#df.to_string()
#df.filter()

# %% [markdown]
# ## clean the item_price column and transform it in a float
# ## reassign the column with the cleaned prices

# %%
df['item_price']=df['item_price'].apply(lambda x:x[1:])
df['item_price']=df['item_price'].astype('float')
df1=df

# %%
#df['item_price'].sum()
df['item_price']
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ## select only the products with quantity equals to 1

# %%
df[df['quantity'] == 1]
# Out:
#       Unnamed: 0  order_id  quantity                              item_name  \
# 0              0         1         1           Chips and Fresh Tomato Salsa
# 1              1         1         1                                   Izze
# 2              2         1         1                       Nantucket Nectar
# 3              3         1         1  Chips and Tomatillo-Green Chili Salsa
# 5              5         3         1                           Chicken Bowl
# ...          ...       ...       ...                                    ...
# 4617        4617      1833         1                          Steak Burrito
# 4618        4618      1833         1                          Steak Burrito
# 4619        4619      1834         1                     Chicken Salad Bowl
# 4620        4620      1834         1                     Chicken Salad Bowl
# 4621        4621      1834         1                     Chicken Salad Bowl
#
# ...

# %% [markdown]
# ####  clean the item_price column and transform it in a float
#
#
# ####  reassign the column with the cleaned prices
#
#
# ####  delete the duplicates in item_name and quantity
#
#
# ####  chipo_filtered
#
# ####  select only the products with quantity equals to 1
#
#
#
# ####  What is the price of each item? print a data frame with only two columns item_name and item_price
#
# ####  Sort by the name of the item
#
#
# ####  What was the quantity of the most expensive item ordered?
#
#
# ####  How many times was a Veggie Salad Bowl ordered?
#
# ####  How many times did someone order more than one Canned Soda?

# %% [markdown]
# ## What is the price of each item? print a data frame with only two columns item_name and item_price

# %%
maxx=df['item_price'].max()
print(df[{'item_name','item_price'}])
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ## What was the quantity of the most expensive item ordered?

# %%
print(maxx)
df[df['item_price'] == maxx]['quantity']
# Out:
# 44.25
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ## Sort by the name of the item

# %%
df.sort_values(by='item_name')
# Out:
#       Unnamed: 0  order_id  quantity          item_name  \
# 3389        3389      1360         2  6 Pack Soft Drink
# 341          341       148         1  6 Pack Soft Drink
# 1849        1849       749         1  6 Pack Soft Drink
# 1860        1860       754         1  6 Pack Soft Drink
# 2713        2713      1076         1  6 Pack Soft Drink
# ...          ...       ...       ...                ...
# 2384        2384       948         1  Veggie Soft Tacos
# 781          781       322         1  Veggie Soft Tacos
# 2851        2851      1132         1  Veggie Soft Tacos
# 1699        1699       688         1  Veggie Soft Tacos
# 1395        1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# ...

# %% [markdown]
# ## How many times was a Veggie Salad Bowl ordered

# %%
#d['Text'].str.contains('AWAIT')
df[ df['item_name'].str.contains('Veggie Salad Bowl')]['quantity'].sum()
# Out:
# 18

# %% [markdown]
# ## How many times did someone order more than one Canned Soda

# %%
cs=df[ df['item_name'].str.contains('Canned Soda')]
cs[cs['quantity'] > 1]['order_id'].count()
# Out:
# 20

# %% [markdown]
# ## delete the duplicates in item_name and quantity

# %%
#print(df1['order_id'].count)
df1.drop_duplicates(subset =['item_name','quantity'],keep = False, inplace = True) 
df1
# Out:
#       Unnamed: 0  order_id  quantity                            item_name  \
# 445          445       193         3                                 Bowl
# 506          506       212         2                        Carnitas Bowl
# 673          673       279         1                                 Bowl
# 674          674       279         1    Chips and Mild Fresh Tomato Salsa
# 1257        1257       511         4         Chips and Fresh Tomato Salsa
# 1555        1555       631         2   Chips and Roasted Chili Corn Salsa
# 1653        1653       668         1                  Veggie Crispy Tacos
# 1903        1903       768         2                Barbacoa Crispy Tacos
# 2235        2235       901         4                          Canned Soda
# 2441        2441       970         5                        Bottled Water
# 2550        2550      1010         2  Chips and Tomatillo-Red Chili Salsa
# 2581        2581      1024         2                     Carnitas Burrito
# ...

# %% [markdown]
# ## Chipko filter

# %%
df1.set_index(['item_name','quantity'])
# Out:
#                                               Unnamed: 0  order_id  \
# item_name                           quantity
# Bowl                                3                445       193
# Carnitas Bowl                       2                506       212
# Bowl                                1                673       279
# Chips and Mild Fresh Tomato Salsa   1                674       279
# Chips and Fresh Tomato Salsa        4               1257       511
# Chips and Roasted Chili Corn Salsa  2               1555       631
# Veggie Crispy Tacos                 1               1653       668
# Barbacoa Crispy Tacos               2               1903       768
# Canned Soda                         4               2235       901
# Bottled Water                       5               2441       970
# Chips and Tomatillo-Red Chili Salsa 2               2550      1010
# Carnitas Burrito                    2               2581      1024
# ...

# %%
df1=df1.drop('Unnamed: 0',axis=1)

df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-e4517e53d6e8> in <module>
# ----> 1 df1=df1.drop('Unnamed: 0',axis=1)
#       2
#       3 df1
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...
