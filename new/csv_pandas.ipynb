# %% [markdown]
# # Load dataset

# %%
import numpy as np
import pandas as pd
tt=pd.read_csv(r'titanic_train.csv')
tt1=pd.read_csv(r'titanic_train.csv')

#tt.keys()
tt
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # Fill nan values in age with average/mean

# %%
tt['Age'].fillna(tt['Age'].mean(), inplace=True)
tt
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %% [markdown]
# # Fill nan values in Cabin with Bfill

# %%
tt['Cabin'].fillna(method='bfill',inplace= True)
tt
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %% [markdown]
# # Fill remaning nan values in Cabin with Ffill

# %%
tt['Cabin'].fillna(method='ffill',inplace= True)
tt
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# ...

# %%
tt1
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # Count of nulls in each col using loop

# %%
col=tt1.keys()
for ss in col:
    x=tt1[ss].isnull().sum()
    if x<1:
        continue
    print ("%s ---- %d" %(ss,x) )
# Out:
# Age ---- 177
# Cabin ---- 687
# Embarked ---- 2

# %% [markdown]
# # Count of nulls using inbuilt function

# %%
tt1.isnull().sum()
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tt1['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
idead=np.where(tt1['Survived'] == 0)
tt1.loc[idead]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 4             4            5         0       3
# 5             5            6         0       3
# 6             6            7         0       1
# 7             7            8         0       3
# ..          ...          ...       ...     ...
# 884         884          885         0       3
# 885         885          886         0       3
# 886         886          887         0       2
# 888         888          889         0       3
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 0                     Braund, Mr. Owen Harris    male  22.0      1      0
# 4                    Allen, Mr. William Henry    male  35.0      0      0
# 5                            Moran, Mr. James    male   NaN      0      0
# 6                     McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
ilive=np.where(tt1['Pclass'] == 1)
tt1.loc[ilive]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 3             3            4         1       1
# 6             6            7         0       1
# 11           11           12         1       1
# 23           23           24         1       1
# ..          ...          ...       ...     ...
# 871         871          872         1       1
# 872         872          873         0       1
# 879         879          880         1       1
# 887         887          888         1       1
# 889         889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
classes=tt1["Pclass"].unique()
x=pd.Categorical(classes)
x.describe()
# Out:
#             counts     freqs
# categories
# 1                1  0.333333
# 2                1  0.333333
# 3                1  0.333333
